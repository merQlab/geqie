# %% [markdown]
# # Experiments for image encoding evaluation

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Google Drive setup

# %%
import os
import subprocess
from pathlib import Path

GEQIE_PATH = Path(os.getcwd()).parent
WORK_DIR = Path(".")  # directory for logs and outputs, overridden in Colab scenario

DRIVE_MOUNT_PATH = Path("/content/drive")
_DRIVE_WORK_DIR = DRIVE_MOUNT_PATH / "MyDrive" / "Colab Notebooks" / "GEQIE"  # overrides WORK_DIR in Colab

CURRENT_PATH = Path(os.path.abspath("."))
IMAGES_PATH = CURRENT_PATH.parent / "experiments" / "generated_images"

try:
    from google.colab import drive

    print("Environment is Google Colab.")

    GEQIE_PATH = Path("/content/geqie")
    print(f"--- GEQIE path set to '{GEQIE_PATH}'")

    IMAGES_PATH = GEQIE_PATH / "experiments" / "generated_images"
    print(f"--- Images path set to '{IMAGES_PATH}'")

    try:
      print(f"--- Mounting Google Drive at '{DRIVE_MOUNT_PATH}'...")
      drive.mount(DRIVE_MOUNT_PATH.as_posix())
      WORK_DIR = _DRIVE_WORK_DIR
    except NotImplementedError:
      print("Drive not implemented error. Skipping.")

    print("Installing dependencies...")

    ! git clone https://github.com/merQlab/geqie.git $GEQIE_PATH 2>/dev/null
    ! uv pip install $GEQIE_PATH 2>/dev/null
    ! uv pip install -r $GEQIE_PATH/experiments/requirements/requirements.in 2>/dev/null

    # Check if GPU is available
    try:
        result = subprocess.run(['nvidia-smi'])
        print("--- NVIDIA GPU detected. Installing qiskit-aer-gpu")
        ! uv pip install qiskit-aer-gpu 2>/dev/null
    except Exception:
        pass

    print("Dependencies installed successfully. (restart may be required -> 'Restart runtime and run all')")
except ModuleNotFoundError as e:
    print("Environment is not Google Colab... skipping.")
except Exception as e:
    print("Error encountered: " + str(e))
# Out:
# Environment is not Google Colab... skipping.

# %% [markdown]
# ### Imports

# %%
from dataclasses import dataclass
from datetime import datetime
from itertools import product
from typing import List

import numpy as np
import pandas as pd

from PIL import Image, ImageOps
from scipy.stats import pearsonr
from tqdm import tqdm

import qiskit
from qiskit_aer import AerSimulator
from qiskit_aer.noise import NoiseModel
from qiskit_aer.noise.errors import depolarizing_error

# %%
import geqie
from geqie.encodings import frqci, frqi, ifrqi, mcqi, ncqi, neqr, qrci, qualpi

# %% [markdown]
# ### Constants

# %%
GRAYSCALE_METHODS = [
    frqi,
    ifrqi,
    neqr,
    qualpi,
]
GRAYSCALE_PATH = IMAGES_PATH / "grayscale"
GRAYSCALE_IMAGE_PATHS = sorted(GRAYSCALE_PATH.glob("*.png"))

RGB_METHODS = [
    frqci,
    mcqi,
    ncqi,
    qrci,
]
RGB_PATH = IMAGES_PATH / "rgb"
RGB_IMAGE_PATHS = sorted(RGB_PATH.glob("*.png"))

# %% [markdown]
# ### Helpers

# %%
def append_row_to_csv(file_path: Path, row: dict) -> None:
    """Append a row to a CSV file, creating the file with headers if it doesn't exist."""
    file_exists = file_path.exists()
    df = pd.DataFrame([row])
    df.to_csv(file_path, mode='a', header=not file_exists, index=False)

# %%
def plot_images_side_by_side(original: np.ndarray, retrieved: np.ndarray) -> None:
    image_original = Image.fromarray(original)
    image_retrieved = Image.fromarray(retrieved)
    display(image_original.resize((image_original.width*30, image_original.height*30), resample=Image.NEAREST))
    display(image_retrieved.resize((image_retrieved.width*30, image_retrieved.height*30), resample=Image.NEAREST))

# %%
def PSNR(original: np.ndarray, retrieved: np.ndarray) -> float:
    mse = np.mean((original - retrieved) ** 2)
    if mse == 0:
        return float("inf")
    max_pixel = 255.0
    psnr = 20 * np.log10(max_pixel / np.sqrt(mse))
    return psnr

# %% [markdown]
# ## Experiments

# %% [markdown]
# ### Configuration

# %%
N_SHOTS = 1024

CSV_RESULTS_PATH = WORK_DIR / "results" 
CSV_RESULTS_PATH.mkdir(parents=True, exist_ok=True)

RESULTS_CSV_FILENAME_TEMPLATE = "{time_of_execution}_{colormode}.csv"

# %% [markdown]
# #### Noise configuration

# %%
NOISE_LEVELS = [0.01, 0.1, 0.2, 0.5, 0.9, 1.0]
NOISE_MODEL_NAME = "depolarizing_1q"

NOISE_N_QUBITS = 10
NOISE_N_TRIALS = 10

# %% [markdown]
# #### Transpilation

# %%
TRANSPILATION_BASIS = ["cx", "u"]

def get_cnot_count(circuit):
    transpiled_circuit = qiskit.transpile(circuit, basis_gates=TRANSPILATION_BASIS, optimization_level=0)
    return transpiled_circuit.count_ops().get("cx", 0)

# %% [markdown]
# #### Results definition

# %%
@dataclass
class ResultsRow:
    method_name: str
    image_name: str
    pcc_clean: float
    psnr_clean: float

    noise_model: str
    noise_levels: List[float]
    pcc_noised: List[float]
    psnr_noised: List[float]

    circuit_depth: int
    circuit_size: int
    cnot_count: int
    n_qubits: int
    n_shots: int

    def to_dict(self) -> dict:
        result = self.__dict__
        noise_levels = result.pop("noise_levels")
        pcc_noised = result.pop("pcc_noised")
        psnr_noised = result.pop("psnr_noised")

        for i, level in enumerate(noise_levels):
            result[f"pcc_noised_{level}"] = pcc_noised[i]
            result[f"psnr_noised_{level}"] = psnr_noised[i]

        return result

# %% [markdown]
# ### Grayscale experiment

# %%
time_of_execution = datetime.now().strftime("%Y_%m_%d__%H_%M_%S")
GRAYSCALE_RESULTS_PATH = CSV_RESULTS_PATH / RESULTS_CSV_FILENAME_TEMPLATE.format(
    time_of_execution=time_of_execution,
    colormode="grayscale",
)

print(f"Saving results to '{GRAYSCALE_RESULTS_PATH}'")

for (method, image_path) in tqdm(list(product(GRAYSCALE_METHODS, GRAYSCALE_IMAGE_PATHS))):
    try:
        method_name = method.__name__.split('.')[-1]
        image_name = image_path.stem

        image = Image.open(image_path)
        image = ImageOps.grayscale(image)
        image = np.asarray(image)

        device = "GPU" if "GPU" in AerSimulator().available_devices() else "CPU"
        circuit = geqie.encode(method.init_function, method.data_function, method.map_function, image)
        result = geqie.simulate(circuit, N_SHOTS, device=device, return_padded_counts=False)
        retrieved_image = method.retrieve_function(result)

        circuit_size = circuit.size()
        circuit_depth = circuit.depth()
        cnot_count = get_cnot_count(circuit)
        num_qubits = circuit.num_qubits

        pcc_clean_image, _ = pearsonr(image.flatten(), retrieved_image.flatten())
        psnr_clean_image = PSNR(image, retrieved_image)

        psnr_noised = []
        pcc_noised = []
        for noise_level in NOISE_LEVELS:
            _psnr_noised = []
            _pcc_noised = []
            for _ in range(NOISE_N_TRIALS):
                circuit = geqie.encode(method.init_function, method.data_function, method.map_function, image)
                
                # add selective noise to random N_NOISE_QUBITS qubits
                qubits_to_noise = sorted(np.random.choice(circuit.num_qubits, size=min(NOISE_N_QUBITS, circuit.num_qubits), replace=False).tolist())
                noise_model = NoiseModel()
                depol_error = depolarizing_error(noise_level, 1)
                [noise_model.add_quantum_error(depol_error, ["unitary"], [qubit]) for qubit in qubits_to_noise]

                result_noised = geqie.simulate(
                    circuit=circuit,
                    n_shots=N_SHOTS,
                    noise_model=noise_model,
                    device=device,
                    return_padded_counts=False,
                )
                retrieved_noised_image = method.retrieve_function(result_noised)

                pcc_noised_image, _ = pearsonr(image.flatten(), retrieved_noised_image.flatten())
                _pcc_noised.append(pcc_noised_image)

                psnr_noised_image = PSNR(image, retrieved_noised_image)
                _psnr_noised.append(psnr_noised_image)
                
                if len(qubits_to_noise) == circuit.num_qubits:
                    break  # all qubits are noised, no need to repeat

            pcc_noised.append(np.mean(_pcc_noised))
            psnr_noised.append(np.mean(_psnr_noised))

        results_row = ResultsRow(
            method_name=method_name,
            image_name=image_name,
            pcc_clean=pcc_clean_image,
            psnr_clean=psnr_clean_image,

            noise_model=NOISE_MODEL_NAME,
            noise_levels=NOISE_LEVELS,
            pcc_noised=pcc_noised,
            psnr_noised=psnr_noised,

            cnot_count=cnot_count,
            circuit_size=circuit_size,
            circuit_depth=circuit_depth,
            n_qubits=num_qubits,
            n_shots=N_SHOTS,
        )

        append_row_to_csv(GRAYSCALE_RESULTS_PATH, results_row.to_dict())
    except MemoryError:
        print(f"MemoryError encountered. Skipping '{method}': '{image_path}'.")
        continue
print("Done.")
# Out:
# Saving results to 'results\2025_12_23__15_50_50_grayscale.csv'
#  14%|█▎        | 13/96 [00:05<00:36,  2.25it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 25
#      23 circuit_size = circuit.size()
#      24 circuit_depth = circuit.depth()
# ---> 25 cnot_count = get_cnot_count(circuit)
#      26 num_qubits = circuit.num_qubits
#      28 pcc_clean_image, _ = pearsonr(image.flatten(), retrieved_image.flatten())
#
# Cell In[11], line 4, in get_cnot_count(circuit)
#       3 def get_cnot_count(circuit):
# ----> 4     transpiled_circuit = qiskit.transpile(circuit, basis_gates=TRANSPILATION_BASIS, optimization_level=0)
#       5     return transpiled_circuit.count_ops().get("cx", 0)
#
# File d:\Biblioteki\Studia\unsynced\geqie\.venv\Lib\site-packages\qiskit\utils\deprecation.py:184, in deprecate_arg.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     171 @functools.wraps(func)
#     172 def wrapper(*args, **kwargs):
#     173     _maybe_warn_and_rename_kwarg(
#     174         args,
#     175         kwargs,
#    (...)    182         predicate=predicate,
#     183     )
# --> 184     return func(*args, **kwargs)
#
# File d:\Biblioteki\Studia\unsynced\geqie\.venv\Lib\site-packages\qiskit\utils\deprecation.py:184, in deprecate_arg.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     171 @functools.wraps(func)
#     172 def wrapper(*args, **kwargs):
#     173     _maybe_warn_and_rename_kwarg(
#     174         args,
#     175         kwargs,
#    (...)    182         predicate=predicate,
#     183     )
# --> 184     return func(*args, **kwargs)
#
#     [... skipping similar frames: deprecate_arg.<locals>.decorator.<locals>.wrapper at line 184 (1 times)]
#
# File d:\Biblioteki\Studia\unsynced\geqie\.venv\Lib\site-packages\qiskit\utils\deprecation.py:184, in deprecate_arg.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     171 @functools.wraps(func)
#     172 def wrapper(*args, **kwargs):
#     173     _maybe_warn_and_rename_kwarg(
#     174         args,
#     175         kwargs,
#    (...)    182         predicate=predicate,
#     183     )
# --> 184     return func(*args, **kwargs)
#
# File d:\Biblioteki\Studia\unsynced\geqie\.venv\Lib\site-packages\qiskit\compiler\transpiler.py:449, in transpile(circuits, backend, basis_gates, inst_map, coupling_map, backend_properties, initial_layout, layout_method, routing_method, translation_method, scheduling_method, instruction_durations, dt, approximation_degree, timing_constraints, seed_transpiler, optimization_level, callback, output_name, unitary_synthesis_method, unitary_synthesis_plugin_config, target, hls_config, init_method, optimization_method, ignore_backend_supplied_default_methods, num_processes, qubits_initially_zero)
#     417     warnings.filterwarnings(
#     418         "ignore",
#     419         category=DeprecationWarning,
#     420         message=".*``backend_properties`` is deprecated as of Qiskit 1.3.*",
#     421         module="qiskit",
#     422     )
#     423     pm = generate_preset_pass_manager(
#     424         optimization_level,
#     425         target=target,
#    (...)    446         qubits_initially_zero=qubits_initially_zero,
#     447     )
# --> 449 out_circuits = pm.run(circuits, callback=callback, num_processes=num_processes)
#     451 for name, circ in zip(output_name, out_circuits):
#     452     circ.name = name
#
# File d:\Biblioteki\Studia\unsynced\geqie\.venv\Lib\site-packages\qiskit\transpiler\passmanager.py:441, in StagedPassManager.run(self, circuits, output_name, callback, num_processes)
#     433 def run(
#     434     self,
#     435     circuits: _CircuitsT,
#    (...)    438     num_processes: int = None,
#     439 ) -> _CircuitsT:
#     440     self._update_passmanager()
# --> 441     return super().run(circuits, output_name, callback, num_processes=num_processes)
#
# File d:\Biblioteki\Studia\unsynced\geqie\.venv\Lib\site-packages\qiskit\transpiler\passmanager.py:464, in _replace_error.<locals>.wrapper(*meth_args, **meth_kwargs)
#     461 @wraps(meth)
#     462 def wrapper(*meth_args, **meth_kwargs):
#     463     try:
# --> 464         return meth(*meth_args, **meth_kwargs)
#     465     except PassManagerError as ex:
#     466         raise TranspilerError(ex.message) from ex
#
# File d:\Biblioteki\Studia\unsynced\geqie\.venv\Lib\site-packages\qiskit\transpiler\passmanager.py:226, in PassManager.run(self, circuits, output_name, callback, num_processes)
#     223 if callback is not None:
#     224     callback = _legacy_style_callback(callback)
# --> 226 return super().run(
#     227     in_programs=circuits,
#     228     callback=callback,
#     229     output_name=output_name,
#     230     num_processes=num_processes,
#     231 )
#
# File d:\Biblioteki\Studia\unsynced\geqie\.venv\Lib\site-packages\qiskit\passmanager\passmanager.py:250, in BasePassManager.run(self, in_programs, callback, num_processes, property_set, **kwargs)
#     246 # If we're not going to run in parallel, we want to avoid spending time `dill` serializing
#     247 # ourselves, since that can be quite expensive.
#     248 if len(in_programs) == 1 or not should_run_in_parallel(num_processes):
#     249     out = [
# --> 250         _run_workflow(program=program, pass_manager=self, callback=callback, **kwargs)
#     251         for program in in_programs
#     252     ]
#     253     if len(in_programs) == 1 and not is_list:
#     254         return out[0]
#
# File d:\Biblioteki\Studia\unsynced\geqie\.venv\Lib\site-packages\qiskit\passmanager\passmanager.py:310, in _run_workflow(program, pass_manager, **kwargs)
#     304 initial_status = WorkflowStatus()
#     306 passmanager_ir = pass_manager._passmanager_frontend(
#     307     input_program=program,
#     308     **kwargs,
#     309 )
# --> 310 passmanager_ir, final_state = flow_controller.execute(
#     311     passmanager_ir=passmanager_ir,
#     312     state=PassManagerState(
#     313         workflow_status=initial_status,
#     314         property_set=PropertySet(),
#     315     ),
#     316     callback=kwargs.get("callback", None),
#     317 )
#     318 # The `property_set` has historically been returned as a mutable attribute on `PassManager`
#     319 # This makes us non-reentrant (though `PassManager` would be dependent on its internal tasks to
#     320 # be re-entrant if that was required), but is consistent with previous interfaces.  We're still
#     321 # safe to be called in a serial loop, again assuming internal tasks are re-runnable.  The
#     322 # conversion to the backend language is also allowed to use the property set, so it must be set
#     323 # before calling it.
#     324 pass_manager.property_set = final_state.property_set
#
# File d:\Biblioteki\Studia\unsynced\geqie\.venv\Lib\site-packages\qiskit\passmanager\base_tasks.py:218, in BaseController.execute(self, passmanager_ir, state, callback)
#     216     return passmanager_ir, state
#     217 while True:
# --> 218     passmanager_ir, state = next_task.execute(
#     219         passmanager_ir=passmanager_ir,
#     220         state=state,
#     221         callback=callback,
#     222     )
#     223     try:
#     224         # Sending the object through the generator implies the custom controllers
#     225         # can always rely on the latest data to choose the next task to run.
#     226         next_task = task_generator.send(state)
#
# File d:\Biblioteki\Studia\unsynced\geqie\.venv\Lib\site-packages\qiskit\transpiler\basepasses.py:195, in TransformationPass.execute(self, passmanager_ir, state, callback)
#     189 def execute(
#     190     self,
#     191     passmanager_ir: PassManagerIR,
#     192     state: PassManagerState,
#     193     callback: Callable = None,
#     194 ) -> tuple[PassManagerIR, PassManagerState]:
# --> 195     new_dag, state = super().execute(
#     196         passmanager_ir=passmanager_ir,
#     197         state=state,
#     198         callback=callback,
#     199     )
#     201     if state.workflow_status.previous_run == RunState.SUCCESS:
#     202         if isinstance(new_dag, DAGCircuit):
#     203             # Copy calibration data from the original program
#
# File d:\Biblioteki\Studia\unsynced\geqie\.venv\Lib\site-packages\qiskit\passmanager\base_tasks.py:98, in GenericPass.execute(self, passmanager_ir, state, callback)
#      96 try:
#      97     if self not in state.workflow_status.completed_passes:
# ---> 98         ret = self.run(passmanager_ir)
#      99         run_state = RunState.SUCCESS
#     100     else:
#
# File d:\Biblioteki\Studia\unsynced\geqie\.venv\Lib\site-packages\qiskit\transpiler\passes\synthesis\unitary_synthesis.py:535, in UnitarySynthesis.run(self, dag)
#     532     if method.supports_target:
#     533         kwargs["target"] = self._target
# --> 535 out = self._run_main_loop(
#     536     dag, qubit_indices, plugin_method, plugin_kwargs, default_method, default_kwargs
#     537 )
#     538 return out
#
# File d:\Biblioteki\Studia\unsynced\geqie\.venv\Lib\site-packages\qiskit\transpiler\passes\synthesis\unitary_synthesis.py:585, in UnitarySynthesis._run_main_loop(self, dag, qubit_indices, plugin_method, plugin_kwargs, default_method, default_kwargs)
#     580 if method.supports_coupling_map:
#     581     kwargs["coupling_map"] = (
#     582         self._coupling_map,
#     583         [qubit_indices[x] for x in node.qargs],
#     584     )
# --> 585 synth_dag = method.run(unitary, **kwargs)
#     586 if synth_dag is None:
#     587     out_dag._apply_op_node_back(node)
#
# File d:\Biblioteki\Studia\unsynced\geqie\.venv\Lib\site-packages\qiskit\transpiler\passes\synthesis\unitary_synthesis.py:1030, in DefaultUnitarySynthesis.run(self, unitary, **options)
#    1025     from qiskit.synthesis.unitary.qsd import (  # pylint: disable=cyclic-import
#    1026         qs_decomposition,
#    1027     )
#    1029     # only decompose if needed. TODO: handle basis better
# -> 1030     synth_circuit = qs_decomposition(unitary) if (basis_gates or target) else None
#    1031 if synth_circuit is None:
#    1032     return None
#
# File d:\Biblioteki\Studia\unsynced\geqie\.venv\Lib\site-packages\qiskit\synthesis\unitary\qsd.py:130, in qs_decomposition(mat, opt_a1, opt_a2, decomposer_1q, decomposer_2q, _depth)
#     128 (u1, u2), vtheta, (v1h, v2h) = scipy.linalg.cossin(mat, separate=True, p=dim_o2, q=dim_o2)
#     129 # left circ
# --> 130 left_circ = _demultiplex(v1h, v2h, opt_a1=opt_a1, opt_a2=opt_a2, _depth=_depth)
#     131 circ.append(left_circ.to_instruction(), qr)
#     132 # middle circ
#
# File d:\Biblioteki\Studia\unsynced\geqie\.venv\Lib\site-packages\qiskit\synthesis\unitary\qsd.py:205, in _demultiplex(um0, um1, opt_a1, opt_a2, _depth)
#     202 circ = QuantumCircuit(nqubits)
#     204 # left gate
# --> 205 left_gate = qs_decomposition(
#     206     wmat, opt_a1=opt_a1, opt_a2=opt_a2, _depth=_depth + 1
#     207 ).to_instruction()
#     208 circ.append(left_gate, range(nqubits - 1))
#     210 # multiplexed Rz
#
# File d:\Biblioteki\Studia\unsynced\geqie\.venv\Lib\site-packages\qiskit\synthesis\unitary\qsd.py:145, in qs_decomposition(mat, opt_a1, opt_a2, decomposer_1q, decomposer_2q, _depth)
#     143         circ.append(ucry, [qr[-1]] + qr[:-1])
#     144     # right circ
# --> 145     right_circ = _demultiplex(u1, u2, opt_a1=opt_a1, opt_a2=opt_a2, _depth=_depth)
#     146     circ.append(right_circ.to_instruction(), qr)
#     148 if opt_a2 and _depth == 0 and dim > 4:
#
# File d:\Biblioteki\Studia\unsynced\geqie\.venv\Lib\site-packages\qiskit\synthesis\unitary\qsd.py:205, in _demultiplex(um0, um1, opt_a1, opt_a2, _depth)
#     202 circ = QuantumCircuit(nqubits)
#     204 # left gate
# --> 205 left_gate = qs_decomposition(
#     206     wmat, opt_a1=opt_a1, opt_a2=opt_a2, _depth=_depth + 1
#     207 ).to_instruction()
#     208 circ.append(left_gate, range(nqubits - 1))
#     210 # multiplexed Rz
#
# File d:\Biblioteki\Studia\unsynced\geqie\.venv\Lib\site-packages\qiskit\synthesis\unitary\qsd.py:130, in qs_decomposition(mat, opt_a1, opt_a2, decomposer_1q, decomposer_2q, _depth)
#     128 (u1, u2), vtheta, (v1h, v2h) = scipy.linalg.cossin(mat, separate=True, p=dim_o2, q=dim_o2)
#     129 # left circ
# --> 130 left_circ = _demultiplex(v1h, v2h, opt_a1=opt_a1, opt_a2=opt_a2, _depth=_depth)
#     131 circ.append(left_circ.to_instruction(), qr)
#     132 # middle circ
#
# File d:\Biblioteki\Studia\unsynced\geqie\.venv\Lib\site-packages\qiskit\synthesis\unitary\qsd.py:205, in _demultiplex(um0, um1, opt_a1, opt_a2, _depth)
#     202 circ = QuantumCircuit(nqubits)
#     204 # left gate
# --> 205 left_gate = qs_decomposition(
#     206     wmat, opt_a1=opt_a1, opt_a2=opt_a2, _depth=_depth + 1
#     207 ).to_instruction()
#     208 circ.append(left_gate, range(nqubits - 1))
#     210 # multiplexed Rz
#
# File d:\Biblioteki\Studia\unsynced\geqie\.venv\Lib\site-packages\qiskit\synthesis\unitary\qsd.py:122, in qs_decomposition(mat, opt_a1, opt_a2, decomposer_1q, decomposer_2q, _depth)
#     120         else:
#     121             decomposer_2q = TwoQubitBasisDecomposer(CXGate())
# --> 122     circ = decomposer_2q(mat)
#     123 else:
#     124     qr = QuantumRegister(nqubits)
#
# File d:\Biblioteki\Studia\unsynced\geqie\.venv\Lib\site-packages\qiskit\synthesis\unitary\qsd.py:114, in qs_decomposition.<locals>.decomp_2q(mat)
#     113 def decomp_2q(mat):
# --> 114     ugate = UnitaryGate(mat)
#     115     qc = QuantumCircuit(2, name="qsd2q")
#     116     qc.append(ugate, [0, 1])
#
# File d:\Biblioteki\Studia\unsynced\geqie\.venv\Lib\site-packages\qiskit\circuit\library\generalized_gates\unitary.py:101, in UnitaryGate.__init__(self, data, label, check_input, num_qubits)
#      98 num_qubits = num_qubits if num_qubits is not None else int(math.log2(input_dim))
#      99 if check_input:
#     100     # Check input is unitary
# --> 101     if not is_unitary_matrix(data):
#     102         raise ValueError("Input matrix is not unitary.")
#     103     # Check input is N-qubit matrix
#
# File d:\Biblioteki\Studia\unsynced\geqie\.venv\Lib\site-packages\qiskit\quantum_info\operators\predicates.py:173, in is_unitary_matrix(mat, rtol, atol)
#     171 mat = np.array(mat)
#     172 # Compute A^dagger.A and see if it is identity matrix
# --> 173 mat = np.conj(mat.T).dot(mat)
#     174 return is_identity_matrix(mat, ignore_phase=False, rtol=rtol, atol=atol)
#
# KeyboardInterrupt:
