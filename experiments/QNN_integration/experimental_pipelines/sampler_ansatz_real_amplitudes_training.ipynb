# %% [markdown]
# # Lightning training — `sampler_ansatz_real_amplitudes`
#
# Trains a `RealAmplitudes` ansatz on GEQIE-encoded image unitaries using `SamplerAnsatzLayer`,
# a pure NumPy/PyTorch statevector layer with analytic parameter-shift gradients (no Qiskit
# `SamplerQNN`/process pool involved).
#
# Pipeline: `GEQIE/FRQI matrices -> UnitaryInputLayer -> SamplerAnsatzLayer(real_amplitudes) -> Linear -> LogSoftmax`.
#
# Note: the adaptive-QCNN ansatz (`build_adaptive_qcnn_ansatz`, used in the `VQCLayer`-based
# baseline notebook) is **not** compatible with `SamplerAnsatzLayer`: its convolution/pooling
# gates parameterize rotations with affine expressions such as `2*theta - pi/2` rather than the
# bare parameter, which `SamplerAnsatzLayer`'s parameter-shift generator extraction rejects. This
# notebook instead uses `real_amplitudes`, the ansatz `SamplerAnsatzLayer` is designed for.

# %% [markdown]
# ## Imports

# %%
import zipfile
from pathlib import Path

import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchinfo
from torch.utils import data as torch_data
from torchmetrics import Accuracy

import lightning as L
from lightning.pytorch.loggers import CSVLogger

from qiskit.circuit.library import real_amplitudes

import geqie_qml
from geqie_qml import UnitaryInputLayer, SamplerAnsatzLayer

print("geqie_qml:", geqie_qml.__file__)
# Out:
# geqie_qml: /home/ODM/rpotempa/geqie/geqie-qml/src/geqie_qml/__init__.py

# %% [markdown]
# ## Configuration

# %%
# --- data ---
IMAGE_SIZE = 16                # MNIST is resized to IMAGE_SIZE x IMAGE_SIZE before FRQI encoding
ENCODING = "frqi"
DATASET_SAMPLE_SIZE = 100      # training images to encode
TEST_SAMPLE_SIZE = 100
VAL_SPLIT = 0.2
BATCH_SIZE = 16
PRECOMPUTED_ZIP = Path(".data") / f".precomputed_sampler_ansatz_{ENCODING}_{IMAGE_SIZE}x{IMAGE_SIZE}.zip"

# --- model ---
N_CLASSES = 10
N_LAYERS = 4                    # real_amplitudes repetitions

torch.manual_seed(42)
np.random.seed(42)

# %% [markdown]
# ## Precompute GEQIE encodings
#
# Encodes a small MNIST subset with FRQI and packages the matrices into a single zip archive
# (`train/` and `test/` folders), the layout expected by `load_precomputed_zip_matrices`.
# Re-runs are skipped once the archive exists.

# %%
def resize_dataset(data: torch.Tensor, size: int) -> np.ndarray:
    resized = torch.nn.functional.interpolate(
        data.unsqueeze(1).float(),
        size=(size, size),
        mode="bilinear",
        align_corners=False,
    ).squeeze(1)
    return resized.numpy().astype(np.uint8)


def build_precomputed_zip(n_workers) -> None:
    if PRECOMPUTED_ZIP.exists():
        print(f"Reusing existing archive: {PRECOMPUTED_ZIP}")
        return

    mnist_train = torchvision.datasets.MNIST(root="./.data", train=True, download=True)
    mnist_test = torchvision.datasets.MNIST(root="./.data", train=False, download=True)

    train_data = resize_dataset(mnist_train.data[:DATASET_SAMPLE_SIZE], IMAGE_SIZE)
    train_labels = mnist_train.targets[:DATASET_SAMPLE_SIZE]
    test_data = resize_dataset(mnist_test.data[:TEST_SAMPLE_SIZE], IMAGE_SIZE)
    test_labels = mnist_test.targets[:TEST_SAMPLE_SIZE]

    stage_dir = PRECOMPUTED_ZIP.parent / PRECOMPUTED_ZIP.stem
    geqie_qml.compute_and_save_circuits(
        data=train_data,
        labels=train_labels,
        save_dir=str(stage_dir / "train"),
        geqie_encoding=ENCODING,
        encoding_params={},
        number_of_workers=n_workers,
    )
    geqie_qml.compute_and_save_circuits(
        data=test_data,
        labels=test_labels,
        save_dir=str(stage_dir / "test"),
        geqie_encoding=ENCODING,
        encoding_params={},
        number_of_workers=n_workers,
    )

    with zipfile.ZipFile(PRECOMPUTED_ZIP, "w", compression=zipfile.ZIP_DEFLATED) as archive:
        for matrix_file in stage_dir.glob("*/*.npz"):
            archive.write(matrix_file, arcname=matrix_file.relative_to(stage_dir).as_posix())
    print(f"Wrote archive: {PRECOMPUTED_ZIP}")


build_precomputed_zip(n_workers=4)
# Out:
# Precomputing 100 images with encoding 'frqi' using 4 worker(s).
# Submitting images: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 517.64image/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [14:02<00:00,  8.43s/image]
# Finished precomputing 100 images into '.data/.precomputed_sampler_ansatz_frqi_16x16/train'.
# Precomputing 100 images with encoding 'frqi' using 4 worker(s).
# Submitting images: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 480.68image/s]
# Processing images: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [29:01<00:00, 17.41s/image]
# Finished precomputing 100 images into '.data/.precomputed_sampler_ansatz_frqi_16x16/test'.
# Wrote archive: .data/.precomputed_sampler_ansatz_frqi_16x16.zip

# %%
train_ds, test_ds = geqie_qml.load_precomputed_zip_matrices(str(PRECOMPUTED_ZIP))

# Infer the qubit count from an actual encoded matrix (2**n x 2**n).
sample_matrix, _ = train_ds[0]
N_QUBITS = int(round(np.log2(sample_matrix.shape[-1])))
print(f"Encoded qubits: {N_QUBITS}")

n_total = len(train_ds)
n_val = int(n_total * VAL_SPLIT)
n_train = n_total - n_val
train_subset, val_subset = torch_data.random_split(
    train_ds, [n_train, n_val], generator=torch.Generator().manual_seed(42)
)

train_loader = torch_data.DataLoader(train_subset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0)
val_loader = torch_data.DataLoader(val_subset, batch_size=BATCH_SIZE, num_workers=0)
test_loader = torch_data.DataLoader(test_ds, batch_size=BATCH_SIZE, num_workers=0)
print(f"Train: {n_train}, Val: {n_val}, Test: {len(test_ds)}")
# Out:
# Encoded qubits: 9
# Train: 80, Val: 20, Test: 100

# %% [markdown]
# ## Model definition
#
# `UnitaryInputLayer` turns each precomputed unitary matrix into the encoded statevector `U|0>`;
# `SamplerAnsatzLayer` then applies the trainable `real_amplitudes` ansatz and returns the full
# `2**N_QUBITS` measurement probability distribution, which feeds the classical head directly.

# %%
ansatz = real_amplitudes(N_QUBITS, reps=N_LAYERS)

model = nn.Sequential(
    UnitaryInputLayer(N_QUBITS),                     # (B, dim, dim) complex -> (B, dim) complex
    SamplerAnsatzLayer(N_QUBITS, ansatz, seed=42),    # (B, dim) complex -> (B, dim) probs
    nn.Linear(2 ** N_QUBITS, N_CLASSES),
    nn.LogSoftmax(dim=-1),
)
torchinfo.summary(model)
# Out:
# Sequential(
#   (0): UnitaryInputLayer(n_qubits=9, dim=512)
#   (1): SamplerAnsatzLayer(n_qubits=9, dim=512, weights=45, param_gates=45, fixed_gates=32)
#   (2): Linear(in_features=512, out_features=10, bias=True)
#   (3): LogSoftmax(dim=-1)
# )
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# Sequential                               --
# ├─UnitaryInputLayer: 1-1                 --
# ├─SamplerAnsatzLayer: 1-2                45
# ├─Linear: 1-3                            5,130
# ├─LogSoftmax: 1-4                        --
# =================================================================
# Total params: 5,175
# Trainable params: 5,175
# Non-trainable params: 0
# =================================================================

# %% [markdown]
# ## Training with Lightning

# %%
class SamplerAnsatzModule(L.LightningModule):
    """Lightning wrapper; the model ends with LogSoftmax, so the loss is NLL."""

    def __init__(self, model: nn.Module, n_classes: int, lr: float = 1e-1):
        super().__init__()
        self.save_hyperparameters(ignore=["model"])
        self.model = model
        self.train_acc = Accuracy(task="multiclass", num_classes=n_classes)
        self.val_acc = Accuracy(task="multiclass", num_classes=n_classes)
        self.test_acc = Accuracy(task="multiclass", num_classes=n_classes)

    def forward(self, x):
        return self.model(x)

    def _shared_step(self, batch):
        x, y = batch
        log_probs = self(x)
        loss = F.nll_loss(log_probs, y)
        preds = log_probs.argmax(dim=-1)
        return loss, preds, y

    def training_step(self, batch, batch_idx):
        loss, preds, y = self._shared_step(batch)
        self.train_acc(preds, y)
        self.log("train_loss", loss, on_step=False, on_epoch=True, prog_bar=True)
        self.log("train_acc",  self.train_acc, on_step=False, on_epoch=True, prog_bar=True)
        self.log("lr", self.trainer.optimizers[0].param_groups[0]["lr"], on_step=False, on_epoch=True, prog_bar=True)
        return loss

    def validation_step(self, batch, batch_idx):
        loss, preds, y = self._shared_step(batch)
        self.val_acc(preds, y)
        self.log("val_loss", loss, on_epoch=True, prog_bar=True)
        self.log("val_acc", self.val_acc, on_epoch=True, prog_bar=True)

    def test_step(self, batch, batch_idx):
        loss, preds, y = self._shared_step(batch)
        self.test_acc(preds, y)
        self.log("test_loss", loss, on_epoch=True, prog_bar=True)
        self.log("test_acc", self.test_acc, on_epoch=True, prog_bar=True)

    def configure_optimizers(self):
        optimizer = torch.optim.Adam(self.parameters(), lr=self.hparams.lr)
        scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
            optimizer, mode="min", factor=0.5, patience=3,
        )
        return {
            "optimizer": optimizer,
            "lr_scheduler": {"scheduler": scheduler, "monitor": "val_loss"},
        }

# %%
module = SamplerAnsatzModule(model, n_classes=N_CLASSES, lr=0.1)
logger = CSVLogger(save_dir="lightning_logs", name="sampler_ansatz_real_amplitudes")

trainer = L.Trainer(
    max_epochs=50,
    accelerator="cpu",
    devices=1,
    logger=logger,
    log_every_n_steps=1,
    enable_progress_bar=True,
    num_sanity_val_steps=0,
    callbacks=[
        L.pytorch.callbacks.EarlyStopping(monitor="val_loss", patience=10, mode="min"),
        L.pytorch.callbacks.TQDMProgressBar(leave=True),
    ],
)

# SamplerAnsatzLayer runs pure NumPy/PyTorch autograd in-process; no process pool needed.
trainer.fit(module, train_dataloaders=train_loader, val_dataloaders=val_loader)
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
#
#   | Name      | Type               | Params | Mode  | FLOPs
# -----------------------------------------------------------------
# 0 | model     | Sequential         | 5.2 K  | train | 0
# 1 | train_acc | MulticlassAccuracy | 0      | train | 0
# 2 | val_acc   | MulticlassAccuracy | 0      | train | 0
# 3 | test_acc  | MulticlassAccuracy | 0      | train | 0
# -----------------------------------------------------------------
# 5.2 K     Trainable params
# 0         Non-trainable params
# 5.2 K     Total params
# 0.021     Total estimated model params size (MB)
# 8         Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# /home/ODM/rpotempa/geqie/.venv/lib/python3.12/site-packages/lightning/pytorch/utilities/_pytree.py:21: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
# /home/ODM/rpotempa/geqie/.venv/lib/python3.12/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:434: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=63` in the `DataLoader` to improve performance.
# /home/ODM/rpotempa/geqie/.venv/lib/python3.12/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:434: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=63` in the `DataLoader` to improve performance.
# Training: |                                                                                                                                                                               | 0/? [00:00<?, ?it/s]
# Epoch 0: 100%|███████████████████████████████████████████████████████████████████████████████| 5/5 [00:34<00:00,  0.14it/s, v_num=0, val_loss=2.380, val_acc=0.000, train_loss=2.300, train_acc=0.138, lr=0.100]
# Epoch 1: 100%|███████████████████████████████████████████████████████████████████████████████| 5/5 [00:44<00:00,  0.11it/s, v_num=0, val_loss=2.420, val_acc=0.200, train_loss=2.150, train_acc=0.175, lr=0.100]
# Epoch 2: 100%|███████████████████████████████████████████████████████████████████████████████| 5/5 [00:56<00:00,  0.09it/s, v_num=0, val_loss=2.420, val_acc=0.200, train_loss=2.060, train_acc=0.237, lr=0.100]
# Epoch 3: 100%|███████████████████████████████████████████████████████████████████████████████| 5/5 [00:50<00:00,  0.10it/s, v_num=0, val_loss=2.330, val_acc=0.250, train_loss=1.960, train_acc=0.400, lr=0.100]
# Epoch 4: 100%|███████████████████████████████████████████████████████████████████████████████| 5/5 [00:37<00:00,  0.13it/s, v_num=0, val_loss=2.270, val_acc=0.400, train_loss=1.870, train_acc=0.675, lr=0.100]
# Epoch 5: 100%|███████████████████████████████████████████████████████████████████████████████| 5/5 [00:38<00:00,  0.13it/s, v_num=0, val_loss=2.190, val_acc=0.400, train_loss=1.780, train_acc=0.775, lr=0.100]
# Epoch 6: 100%|███████████████████████████████████████████████████████████████████████████████| 5/5 [00:38<00:00,  0.13it/s, v_num=0, val_loss=2.110, val_acc=0.450, train_loss=1.690, train_acc=0.825, lr=0.100]
# Epoch 7: 100%|███████████████████████████████████████████████████████████████████████████████| 5/5 [00:52<00:00,  0.10it/s, v_num=0, val_loss=2.070, val_acc=0.400, train_loss=1.610, train_acc=0.812, lr=0.100]
# Epoch 8: 100%|███████████████████████████████████████████████████████████████████████████████| 5/5 [00:36<00:00,  0.14it/s, v_num=0, val_loss=2.030, val_acc=0.450, train_loss=1.520, train_acc=0.837, lr=0.100]
# Epoch 9: 100%|███████████████████████████████████████████████████████████████████████████████| 5/5 [00:40<00:00,  0.12it/s, v_num=0, val_loss=2.000, val_acc=0.500, train_loss=1.450, train_acc=0.850, lr=0.100]
# Epoch 10: 100%|██████████████████████████████████████████████████████████████████████████████| 5/5 [00:33<00:00,  0.15it/s, v_num=0, val_loss=1.960, val_acc=0.500, train_loss=1.380, train_acc=0.837, lr=0.100]
# Epoch 11: 100%|██████████████████████████████████████████████████████████████████████████████| 5/5 [00:58<00:00,  0.09it/s, v_num=0, val_loss=1.900, val_acc=0.550, train_loss=1.300, train_acc=0.875, lr=0.100]
# Epoch 12: 100%|██████████████████████████████████████████████████████████████████████████████| 5/5 [00:52<00:00,  0.10it/s, v_num=0, val_loss=1.870, val_acc=0.550, train_loss=1.230, train_acc=0.925, lr=0.100]
# Epoch 13: 100%|██████████████████████████████████████████████████████████████████████████████| 5/5 [00:47<00:00,  0.11it/s, v_num=0, val_loss=1.830, val_acc=0.550, train_loss=1.170, train_acc=0.938, lr=0.100]
# Epoch 14: 100%|██████████████████████████████████████████████████████████████████████████████| 5/5 [00:54<00:00,  0.09it/s, v_num=0, val_loss=1.790, val_acc=0.550, train_loss=1.110, train_acc=0.962, lr=0.100]
# Epoch 15: 100%|██████████████████████████████████████████████████████████████████████████████| 5/5 [00:49<00:00,  0.10it/s, v_num=0, val_loss=1.750, val_acc=0.550, train_loss=1.050, train_acc=0.962, lr=0.100]
# Epoch 16: 100%|██████████████████████████████████████████████████████████████████████████████| 5/5 [00:44<00:00,  0.11it/s, v_num=0, val_loss=1.730, val_acc=0.550, train_loss=0.998, train_acc=0.975, lr=0.100]
# Epoch 17: 100%|██████████████████████████████████████████████████████████████████████████████| 5/5 [00:27<00:00,  0.18it/s, v_num=0, val_loss=1.670, val_acc=0.550, train_loss=0.951, train_acc=0.975, lr=0.100]
# Epoch 18: 100%|██████████████████████████████████████████████████████████████████████████████| 5/5 [00:25<00:00,  0.20it/s, v_num=0, val_loss=1.670, val_acc=0.550, train_loss=0.902, train_acc=0.975, lr=0.100]
# Epoch 19: 100%|██████████████████████████████████████████████████████████████████████████████| 5/5 [00:33<00:00,  0.15it/s, v_num=0, val_loss=1.670, val_acc=0.550, train_loss=0.846, train_acc=0.988, lr=0.100]
# Epoch 20: 100%|██████████████████████████████████████████████████████████████████████████████| 5/5 [00:49<00:00,  0.10it/s, v_num=0, val_loss=1.640, val_acc=0.550, train_loss=0.820, train_acc=0.988, lr=0.100]
# Epoch 21: 100%|██████████████████████████████████████████████████████████████████████████████| 5/5 [00:54<00:00,  0.09it/s, v_num=0, val_loss=1.590, val_acc=0.550, train_loss=0.779, train_acc=0.988, lr=0.100]
# Epoch 22: 100%|██████████████████████████████████████████████████████████████████████████████| 5/5 [00:47<00:00,  0.11it/s, v_num=0, val_loss=1.590, val_acc=0.550, train_loss=0.738, train_acc=0.988, lr=0.100]
# Epoch 23: 100%|██████████████████████████████████████████████████████████████████████████████| 5/5 [00:43<00:00,  0.11it/s, v_num=0, val_loss=1.560, val_acc=0.600, train_loss=0.710, train_acc=0.975, lr=0.100]
# Epoch 24: 100%|██████████████████████████████████████████████████████████████████████████████| 5/5 [00:42<00:00,  0.12it/s, v_num=0, val_loss=1.550, val_acc=0.600, train_loss=0.662, train_acc=0.988, lr=0.100]
# Epoch 25: 100%|██████████████████████████████████████████████████████████████████████████████| 5/5 [00:46<00:00,  0.11it/s, v_num=0, val_loss=1.530, val_acc=0.600, train_loss=0.636, train_acc=0.988, lr=0.100]
# Epoch 26: 100%|██████████████████████████████████████████████████████████████████████████████| 5/5 [00:44<00:00,  0.11it/s, v_num=0, val_loss=1.520, val_acc=0.550, train_loss=0.607, train_acc=0.975, lr=0.100]
# Epoch 27: 100%|██████████████████████████████████████████████████████████████████████████████| 5/5 [00:37<00:00,  0.14it/s, v_num=0, val_loss=1.510, val_acc=0.600, train_loss=0.588, train_acc=1.000, lr=0.100]
# Epoch 28: 100%|██████████████████████████████████████████████████████████████████████████████| 5/5 [00:32<00:00,  0.16it/s, v_num=0, val_loss=1.490, val_acc=0.600, train_loss=0.555, train_acc=0.988, lr=0.100]
# Epoch 29: 100%|██████████████████████████████████████████████████████████████████████████████| 5/5 [00:32<00:00,  0.15it/s, v_num=0, val_loss=1.460, val_acc=0.600, train_loss=0.540, train_acc=1.000, lr=0.100]
# Epoch 30: 100%|██████████████████████████████████████████████████████████████████████████████| 5/5 [00:31<00:00,  0.16it/s, v_num=0, val_loss=1.460, val_acc=0.550, train_loss=0.524, train_acc=0.975, lr=0.100]
# Epoch 31: 100%|██████████████████████████████████████████████████████████████████████████████| 5/5 [00:37<00:00,  0.13it/s, v_num=0, val_loss=1.450, val_acc=0.600, train_loss=0.498, train_acc=1.000, lr=0.100]
# Epoch 32: 100%|██████████████████████████████████████████████████████████████████████████████| 5/5 [00:39<00:00,  0.13it/s, v_num=0, val_loss=1.460, val_acc=0.600, train_loss=0.471, train_acc=0.988, lr=0.100]
# Epoch 33: 100%|██████████████████████████████████████████████████████████████████████████████| 5/5 [00:35<00:00,  0.14it/s, v_num=0, val_loss=1.440, val_acc=0.600, train_loss=0.440, train_acc=1.000, lr=0.100]
# Epoch 34: 100%|██████████████████████████████████████████████████████████████████████████████| 5/5 [00:35<00:00,  0.14it/s, v_num=0, val_loss=1.430, val_acc=0.600, train_loss=0.429, train_acc=1.000, lr=0.100]
# Epoch 35: 100%|██████████████████████████████████████████████████████████████████████████████| 5/5 [00:24<00:00,  0.20it/s, v_num=0, val_loss=1.420, val_acc=0.600, train_loss=0.418, train_acc=1.000, lr=0.100]
# Epoch 36: 100%|██████████████████████████████████████████████████████████████████████████████| 5/5 [00:21<00:00,  0.24it/s, v_num=0, val_loss=1.440, val_acc=0.600, train_loss=0.395, train_acc=1.000, lr=0.100]
# Epoch 37: 100%|██████████████████████████████████████████████████████████████████████████████| 5/5 [00:21<00:00,  0.23it/s, v_num=0, val_loss=1.380, val_acc=0.600, train_loss=0.378, train_acc=1.000, lr=0.100]
# Epoch 38: 100%|██████████████████████████████████████████████████████████████████████████████| 5/5 [00:26<00:00,  0.19it/s, v_num=0, val_loss=1.430, val_acc=0.600, train_loss=0.368, train_acc=1.000, lr=0.100]
# Epoch 39: 100%|██████████████████████████████████████████████████████████████████████████████| 5/5 [00:31<00:00,  0.16it/s, v_num=0, val_loss=1.380, val_acc=0.600, train_loss=0.351, train_acc=1.000, lr=0.100]
# Epoch 40: 100%|██████████████████████████████████████████████████████████████████████████████| 5/5 [00:33<00:00,  0.15it/s, v_num=0, val_loss=1.400, val_acc=0.600, train_loss=0.336, train_acc=1.000, lr=0.100]
# Epoch 41: 100%|██████████████████████████████████████████████████████████████████████████████| 5/5 [00:34<00:00,  0.15it/s, v_num=0, val_loss=1.390, val_acc=0.600, train_loss=0.323, train_acc=1.000, lr=0.100]
# Epoch 42: 100%|██████████████████████████████████████████████████████████████████████████████| 5/5 [00:35<00:00,  0.14it/s, v_num=0, val_loss=1.390, val_acc=0.600, train_loss=0.320, train_acc=1.000, lr=0.100]
# Epoch 43: 100%|██████████████████████████████████████████████████████████████████████████████| 5/5 [00:37<00:00,  0.13it/s, v_num=0, val_loss=1.380, val_acc=0.600, train_loss=0.306, train_acc=1.000, lr=0.100]
# Epoch 44: 100%|██████████████████████████████████████████████████████████████████████████████| 5/5 [00:41<00:00,  0.12it/s, v_num=0, val_loss=1.390, val_acc=0.600, train_loss=0.300, train_acc=1.000, lr=0.050]
# Epoch 45: 100%|██████████████████████████████████████████████████████████████████████████████| 5/5 [00:35<00:00,  0.14it/s, v_num=0, val_loss=1.380, val_acc=0.600, train_loss=0.289, train_acc=1.000, lr=0.050]
# Epoch 46: 100%|██████████████████████████████████████████████████████████████████████████████| 5/5 [00:34<00:00,  0.15it/s, v_num=0, val_loss=1.370, val_acc=0.600, train_loss=0.283, train_acc=1.000, lr=0.050]
# Epoch 47: 100%|██████████████████████████████████████████████████████████████████████████████| 5/5 [00:39<00:00,  0.13it/s, v_num=0, val_loss=1.370, val_acc=0.600, train_loss=0.276, train_acc=1.000, lr=0.050]
# Epoch 48: 100%|██████████████████████████████████████████████████████████████████████████████| 5/5 [00:35<00:00,  0.14it/s, v_num=0, val_loss=1.380, val_acc=0.600, train_loss=0.282, train_acc=1.000, lr=0.050]
# Epoch 49: 100%|██████████████████████████████████████████████████████████████████████████████| 5/5 [00:27<00:00,  0.18it/s, v_num=0, val_loss=1.370, val_acc=0.600, train_loss=0.265, train_acc=1.000, lr=0.050]
# `Trainer.fit` stopped: `max_epochs=50` reached.

# %%
test_metrics = trainer.test(module, dataloaders=test_loader)
test_metrics
# Out:
# /home/ODM/rpotempa/geqie/.venv/lib/python3.12/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:434: The 'test_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=63` in the `DataLoader` to improve performance.
# Testing DataLoader 0: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 7/7 [00:12<00:00,  0.57it/s]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#         test_acc             0.699999988079071
#         test_loss           1.2043476104736328
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# [{'test_loss': 1.2043476104736328, 'test_acc': 0.699999988079071}]

# %% [markdown]
# ## Training curves

# %%
import pandas as pd
import plotly.graph_objects as go
from plotly.subplots import make_subplots

TRAIN_COLOR = "#1f77b4"
VAL_COLOR = "#ff7f0e"

metrics = pd.read_csv(f"{trainer.logger.log_dir}/metrics.csv")

fig = make_subplots(rows=1, cols=2, subplot_titles=("Loss", "Accuracy"))
for cols, col_idx in [(["train_loss", "val_loss"], 1), (["train_acc", "val_acc"], 2)]:
    for col in cols:
        if col not in metrics:
            continue
        subset = metrics.dropna(subset=[col])
        color = TRAIN_COLOR if col.startswith("train") else VAL_COLOR
        fig.add_trace(
            go.Scatter(
                x=subset["epoch"],
                y=subset[col],
                mode="lines+markers",
                name=col,
                line=dict(color=color),
                marker=dict(color=color),
            ),
            row=1,
            col=col_idx,
        )

fig.update_xaxes(title_text="Epoch")
fig.update_layout(height=400, width=900, title_text="sampler_ansatz_real_amplitudes")
fig.show()
